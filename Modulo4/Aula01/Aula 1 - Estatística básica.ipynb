# %% [markdown]
# # Aula 1

# %% [markdown]
# Conteúdo da aula de hoje
#
# - Estatística Básica (variáveis, qualitativas, quantitativas, tabela de frequência, medidas resumo)
# - Gráficos (barras, setores, perfil, histograma, dispersão, boxplot)
# - Análise descritiva através de gráficos (tendência central, variância, forma, detecção de anomalias)
# - Tabela de dupla entrada ou contingência

# %% [markdown]
# # 0 - Bibliotecas e arquivos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# biblioteca que já tem vários datasets embutidos

mpg = sns.load_dataset('mpg')

# informações sobre o dataset
# https://archive.ics.uci.edu/ml/datasets/auto+mpg
# Os dados referem-se ao consumo de combustível em milhas por galão (mpg)

# mpg, cilindros, cilindrada, potência, peso, aceleração, ano/modelo, origem, nome do carro
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # 1 - Introdução

# %% [markdown]
# ## 1.1 - Estatística em ciência de dados

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Além de desatualizada, não há concenso no uso dessa figura porém não há como discutir a importância da estatística na área de ciência de dados.

# %% [markdown]
# ## 1.2 - Por onde começar?

# %% [markdown]
# Existem algumas metodologias e processos para definir como trabalhar e gerir projetos de ciência de dados. A figura abaixo, mesmo que desatualizada, mostra alguns deles.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Você pode criar o seu próprio método ou utilizar um deles. Em uma pesquisa publicada pela KDnugget (dica de blog para seguir: https://www.kdnuggets.com/) em 2014, revela a grande preferência do uso da metodologia CRISP-DM.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Como você pode ver, tudo gira em função dos dados. Então vamos ver os tipos de dados de acordo com a estatística

# %% [markdown]
# # 2 - Estatística básica

# %% [markdown]
# ## 2.1 - Tipos de Variáveis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Variavéis quantitativas** -- seus dados são expressados em escala numérica. Podem ser discretos ou contínuos
#
#
#     - Discretos: Só pode assumir valores inteiros dentro de um intervalo de dados. Ex: Número de banheiros, número de filhos
#
#     - Contínuos: Pode assumir qualquer valor dentro de um intervalo de dados. Ex: Salário, temperatura
#
#
# - **Variavéis qualitativas** -- seus dados são categorias. Podem ser ordinais ou nominais
#
#
#     - Ordinais: Existe uma ordem ou grau entre os dados. Ex: Classe social, escolaridade, NPS
#
#     - Nominais: Não existe ordem entre os dados categóricos. Ex: Sexo, estado civil, país de origem

# %% [markdown]
# Exemplo

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# - Dados Quantitativos:
#     - Discretos: cilindros, ano de fabricação
#     - Contínuos: mpg, cilindrada, potência, peso, aceleração
#
# - Dados Qualitativos:
#     - Ordinais:
#     - Nominais: origem, nome

# %%
print("Indentidade de Genero: \n", ["Homem", "Mulher", "Nao-Binario"])
# Out:
# Indentidade de Genero:
#  ['Homem', 'Mulher', 'Nao-Binario']

# %% [markdown]
# - [X] Nominal
# - [ ] Ordinal

# %%
print("Porte da Empresa: \n", ["MEI", "ME", "Varejo", "Corporate"])
# Out:
# Porte da Empresa:
#  ['MEI', 'ME', 'Varejo', 'Corporate']

# %% [markdown]
# - [ ] Nominal
# - [X] Ordinal

# %%
print("Escolaridade: \n", ["Ensino Fundamental", "Ensino Medio", "Graduacao", "Mestrado", "Doutorado"])
# Out:
# Escolaridade:
#  ['Ensino Fundamental', 'Ensino Medio', 'Graduacao', 'Mestrado', 'Doutorado']

# %% [markdown]
# - [ ] Nominal
# - [X] Ordinal

# %%
print("Ativo Financeiro: \n", ["Renda Fixa", "Acoes", "FII", "COE"])
# Out:
# Ativo Financeiro:
#  ['Renda Fixa', 'Acoes', 'FII', 'COE']

# %% [markdown]
# - [X] Nominal
# - [ ] Ordinal

# %%
print("IMC: \n", ["Magreza", "Saudavel", "Sobrepeso", "Obeso"])
# Out:
# IMC:
#  ['Magreza', 'Saudavel', 'Sobrepeso', 'Obeso']

# %% [markdown]
# - [ ] Nominal
# - [X] Ordinal

# %%
print("Clima: \n", ["Chuvoso", "Ensolarado", "Com Neblina"])
# Out:
# Clima:
#  ['Chuvoso', 'Ensolarado', 'Com Neblina']

# %% [markdown]
# - [X] Nominal
# - [ ] Ordinal

# %% [markdown]
# Bônus:
#
# - base, **dataset**, conjunto de dados, database, dataframe, tabela

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Records: Case, example, instance, observation -> Linhas (registros)
#
# - Features: Attribute, input, predictor, variable -> Colunas (características)
#
# - Target: Outcome, Response, dependet variable -> Saída/classes
#
# - Index (índices)

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## 2.2 - Medidas de posição

# %% [markdown]
# ### 2.2.1 - Média
#
# Seja $X$ uma variável quantitativa e $x_1,x_2,x_3, ...$ os valores assumidos por X. Define-se média de $\overline{x}$ como sendo :
#
#
# $$\overline{x} = \frac{\sum_{i=1}^{n}x_i}{n}= \frac{x_1+ x_2 + x_3 +... +x_n}{n}$$

# %%
mpg['mpg'].mean()
# Out:
# 23.514572864321615

# %% [markdown]
# Com o critério sugerido pelo Bruno

# %%
mpg.groupby('cylinders')[['mpg']].mean()
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %%
# análise gráfica-> dados quantitativos contínuos

sns.histplot(mpg['mpg'])
plt.axvline(mpg['mpg'].mean(), color='red', label='média')

plt.title('Distribuição de consumo dos carros')
plt.show()

# %%
sns.histplot(mpg['weight'])
plt.axvline(mpg['weight'].mean(), color='red', label='média')
plt.title('Distribuição do peso dos carros')
plt.show()

# %% [markdown]
# ## 2.2.2 - Mediana
#
# A **mediana** de uma variável é um número tal que há o mesmo número de observações maiores e menores do que ele, ocupando assim a posição central da série de observações.
#
#
# - - Mediana de $X = X_{\frac{n+1}{2}}$ `Se tamanho da amostra ímpar`
#
#
# - - Mediana de $X = \frac{X_{\frac{n}{2}}+ X_{\frac{n+1}{2}}}{2}$ `Se tamanho da amostra par`
#
# Como os valores de **indice no python** começam em `0`, devemos nos atentar que a equação acima deve ficar como:
#
# - - Mediana de $X = X_{\frac{n}{2}}$ `Se tamanho da amostra par`
#
#
# - - Mediana de $X = \frac{X_{\frac{n-1}{2}}+ X_{\frac{n}{2}}}{2}$ `Se tamanho da amostra ímpar`
