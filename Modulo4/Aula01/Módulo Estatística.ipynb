# %% [markdown]
# # Módulo Estatística

# %% [markdown]
# **Cronograma**

# %% [markdown]
# | 2ª                                                                 | 4ª                                          | 6ª                      |
# |------------------------------------------------------------|---------------------------------------------|-------------------------|
# |                                                            | **06/out**                                  | **08/out**              |
# |                                                                    | Apresentação / Introdução à Estatística     | Estatística Básica      |
# |                                                            |                                             |                         |
# | **11/out**                                                         | **13/out**                                  | **15/out**              |
# | EMENDA   FERIADO                                                   | Probabilidade                               | Modelos Probabilísticos |
# |                                                                    |                                             |                         |
# | **18/out**                                                         | **20/out**                                  | **22/out**              |
# | Exercícios I                                                       | Distribuições e Teorema Central do   Limite | Teste de Hipótese       |
# |                                                                    |                                             |                         |
# | **25/out**                                                         | **27/out**                                   | **29/out**              |
# | Estimação e Inferência   Baesiana                                  | Exercícios II                               | Prova I                 |
# |                                                                    |                                             |                         |
# | **01/nov**                                                         | **03/nov**                                  | **05/nov**              |
# | EMENDA   FERIADO                                                   | Feedback Prova I \| Regressão I             | Regressão II            |
# |                                                                    |                                             |                         |
# | **08/nov**                                                         | **10/nov**                                  | **12/nov**              |
# | Séries Temporais I                                                 | Séries Temporais II                         | Regressão Logística     |
# |                                                                    |                                             |                         |
# | **15/nov**                                                         | **17/nov**                                  | **19/nov**              |
# | FERIADO                                                            | Monitoria do Projeto                        | Exercícios III    |
# |                                                                    |                                             |                         |
# | **22/nov**                                                         |                                             |                         |
# | Entrega do Projeto \| Feedback do Projeto \| Avaliação do Módulo |                                             |                         |

# %% [markdown]
# **Recomendação de livro**

# %% [markdown]
# - Practical statistics for data scientists - **Second edition**
#     - Usando R e Python
#     - Só tem em inglês
#
#
# - Practical statistics for data scientists | Estatística práica para cientista de dados (em português) -> Primeira edição
#     - Só tem exemplos em R

# %% [markdown]
# * Segunda edição
# ![image-2.png](attachment:image-2.png)
# * Primeira edição
# ![image.png](attachment:image.png)

# %% [markdown]
# https://github.com/gedeck/practical-statistics-for-data-scientists

# %% [markdown]
# **Avaliação**
#
# - 1 prova: Realizada dia 29/10
# - 1 projeto: Entregue dia 22/11
#
#
# **Material e presença no class**
#
# **Lista de exercícios durante a aula**

# %% [markdown]
# ![image.png](attachment:image.png)
