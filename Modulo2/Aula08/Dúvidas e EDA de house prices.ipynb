# %% [markdown]
# # Monitoria

# %% [markdown]
# Link da videochamada: https://meet.google.com/mdu-jaor-ehw
# Toda terça feira 19h às 20h

# %% [markdown]
# # Melhores práticas

# %% [markdown]
# https://www.python.org/dev/peps/pep-0008/

# %%
def funcao(x,y,z):
    a=x+y
    b= f'numero de y é: {y}'
    c=      'texto: ' + str(z)
    return a,b,c

# %%
def funcao(x, y, z):
    a = x + y
    b = f'numero de y é: {y}'
    c = 'texto: ' + str(z)
    return a, b, c

# %%
funcao(1,2,3)
# Out:
# (3, 'numero de y é: 2', 'texto3')

# %% [markdown]
# # Dúvida f-string

# %%
x = 10
y = 20

print('A formatação você escolhe, pode ser o valor de x ou de y')
print('*********Várias alternativas************\n')
print('A formatação você escolhe, pode ser o valor de {} ou de {}'.format(x,y))
print('A formatação você escolhe, pode ser o valor de ' + str(x) + ' ou de '+str(y))
print(f'A formatação você escolhe, pode ser o valor de {x} ou de {y}')
# Out:
# A formatação você escolhe, pode ser o valor de x ou de y
# *********Várias alternativas************
#
# A formatação você escolhe, pode ser o valor de 10 ou de 20
# A formatação você escolhe, pode ser o valor de 10 ou de 20
# A formatação você escolhe, pode ser o valor de 10 ou de 20

# %% [markdown]
# # Exercício de pandas

# %% [markdown]
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %% [markdown]
# Dataset é um conjunto de dados, uma base de dados
# Dataframe é uma estrutura do pandas que carrega ou cria um dataset

# %% [markdown]
# Esse dataset contém informações sobre casas e seus valores.
# O objetivo (da competição) é usar as informações das casas para determinar o valor de venda dado que temos as informações e preços de algumas casas  que foram vendidas

# %%
import pandas as pd

pd.options.display.max_columns = 100 # mostra até 100 colunas no dataframe (visualização)

df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
import missingno as msno 
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %%
# A classificação geral de zoneamento
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
df['MSZoning'].nunique()
# Out:
# 5

# %%
df['MSZoning'].value_counts(dropna=False)
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
# Target : preço da casa --> a coluna SalePrice

df['SalePrice'].mean()
# Out:
# 180921.19589041095

# %%
df['SalePrice'].min() # menor valor de casa vendida
# Out:
# 34900

# %%
# valor mais alto da casa vendida
df['SalePrice'].max()
# Out:
# 755000

# %%
# Informações das casas vendidas acima
df[(df['SalePrice'] == df['SalePrice'].min()) |
   (df['SalePrice'] == df['SalePrice'].max())]  # selecionando a casa que tem o menor valor
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495  496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 495         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 691         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 495       Norm     1Fam     1Story            4            5       1920
# 691       Norm     1Fam     2Story           10            6       1994
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 495          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 691          1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
# Informações das casas que tem 3 banheiros completos e área maior que 15000 feet square
df[(df['FullBath'] == 3) & (df['LotArea'] > 15000)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 320    321          60       RL        111.0    16259   Pave   NaN      Reg
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 529    530          20       RL          NaN    32668   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 848    849          50       RL         75.0    45600   Pave   NaN      IR2
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1173  1174          50       RL        138.0    18030   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# ...

# %%
# quero o tamanho médio em cada uma das zonas
df.groupby(['MSZoning'])[['LotArea']].mean() # ou df.groupby(['MSZoning'])['LotArea'].mean()
# Out:
#                LotArea
# MSZoning
# C (all)    9501.300000
# FV         6638.861538
# RH         7380.062500
# RL        11571.814075
# RM         6379.775229

# %%
# quero no dataframe acima valor médio de venda

# %%
df.groupby(['MSZoning']).agg({'LotArea':'median', 'SalePrice':'mean', 'Id':'count', 'FullBath':'median'})
# Out:
#           LotArea      SalePrice    Id  FullBath
# MSZoning
# C (all)    8606.0   74528.000000    10       1.0
# FV         7500.0  214014.061538    65       2.0
# RH         7468.0  131558.375000    16       1.5
# RL        10004.0  191004.994787  1151       2.0
# RM         6000.0  126316.830275   218       1.0

# %%
# Criando a coluna faixa_valor
df['faixa_valor'] = pd.cut(df['SalePrice'], 5)

# %%
df.head(7)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# ...

# %%
# configuração do lote
df['LotConfig'].value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
df.groupby(['faixa_valor'])[['FullBath', 'LotArea', 'PoolArea']].mean()
# Out:
#                       FullBath       LotArea    PoolArea
# faixa_valor
# (34179.9, 178920.0]   1.298507   8775.524684    1.212400
# (178920.0, 322940.0]  1.935039  12402.592520    4.757874
# (322940.0, 466960.0]  2.028571  16742.285714    0.000000
# (466960.0, 610980.0]  2.571429  21824.714286    0.000000
# (610980.0, 755000.0]  2.750000  21459.250000  138.750000

# %%
# dataframe com Configuração do lote por zoneamento e média de preço vendido
# df1 = df.pivot_table(index='MSZoning', columns='FullBath', values= 'SalePrice', aggfunc=np.median).fillna(0)

# QUantidade de casas em relaçao a zona e quantidade de banheiro
df1 = df.pivot_table(index='MSZoning', columns='FullBath', values= 'Id', aggfunc='count').fillna(0)
df1
# Out:
# FullBath    0      1      2     3
# MSZoning
# C (all)   1.0    8.0    1.0   0.0
# FV        0.0    2.0   61.0   2.0
# RH        0.0    8.0    8.0   0.0
# RL        8.0  473.0  641.0  29.0
# RM        0.0  159.0   57.0   2.0

# %%
# resetar o indice
df1.reset_index(inplace=True) #ou df2 = df1.reset_index()

# %%
df1
# Out:
# FullBath MSZoning    0      1      2     3
# 0         C (all)  1.0    8.0    1.0   0.0
# 1              FV  0.0    2.0   61.0   2.0
# 2              RH  0.0    8.0    8.0   0.0
# 3              RL  8.0  473.0  641.0  29.0
# 4              RM  0.0  159.0   57.0   2.0

# %%
# para ordenar o dataframe com relação a coluna 2 - ordem decrescente
df1 = df1.sort_values(2, ascending=False)
df1
# Out:
# FullBath MSZoning    0      1      2     3
# 3              RL  8.0  473.0  641.0  29.0
# 1              FV  0.0    2.0   61.0   2.0
# 4              RM  0.0  159.0   57.0   2.0
# 2              RH  0.0    8.0    8.0   0.0
# 0         C (all)  1.0    8.0    1.0   0.0

# %%
# quero adionar 1 casa em todas as zonas e banheiros

df1[0] = df1[0] + 1
df1
# Out:
# FullBath MSZoning    0      1      2     3
# 3              RL  9.0  473.0  641.0  29.0
# 1              FV  1.0    2.0   61.0   2.0
# 4              RM  1.0  159.0   57.0   2.0
# 2              RH  1.0    8.0    8.0   0.0
# 0         C (all)  2.0    8.0    1.0   0.0

# %%
df1[[0, 1, 2, 3]].applymap(lambda x: x + 1)
# Out:
# FullBath     0      1      2     3
# 3         10.0  474.0  642.0  30.0
# 1          2.0    3.0   62.0   3.0
# 4          2.0  160.0   58.0   3.0
# 2          2.0    9.0    9.0   1.0
# 0          3.0    9.0    2.0   1.0

# %%
def func(x):
    x = x + 1
    return x


df1[[0, 1, 2, 3]].applymap(func)
# Out:
# FullBath     0      1      2     3
# 3         10.0  474.0  642.0  30.0
# 1          2.0    3.0   62.0   3.0
# 4          2.0  160.0   58.0   3.0
# 2          2.0    9.0    9.0   1.0
# 0          3.0    9.0    2.0   1.0

# %%
def func(x):
    x = x + 1
    return x


df1[[0, 1, 2, 3]].apply(func)
# Out:
# FullBath     0      1      2     3
# 3         10.0  474.0  642.0  30.0
# 1          2.0    3.0   62.0   3.0
# 4          2.0  160.0   58.0   3.0
# 2          2.0    9.0    9.0   1.0
# 0          3.0    9.0    2.0   1.0

# %%
# a quantidade total de casas que tem 2 banheiros
df1[2].sum()
# Out:
# 768.0

# %%
# Apenas para ilustrar vamos juntar o df nele mesmo
# "duplicar"
df2 = pd.concat([df, df], axis=0)
df2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df2.shape
# Out:
# (2920, 82)

# %%
# eliminar linhas duplicadas
df2.drop_duplicates(inplace=True) 
df2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
# substituir o C (all) da coluna MSZoning por C
df['MSZoning'] = df['MSZoning'].str.replace('C (all)', 'C', regex=False)

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C', 'FV', 'RH'], dtype=object)

# %%
# Renomear LotArea por AreaTotal
df.rename(columns={'LotArea':'AreaTotal'}, inplace=True)

# %%
df.replace('RL','RA') # altera/replace o dataframe inteiro
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  AreaTotal Street Alley LotShape  \
# 0        1          60       RA         65.0       8450   Pave   NaN      Reg
# 1        2          20       RA         80.0       9600   Pave   NaN      Reg
# 2        3          60       RA         68.0      11250   Pave   NaN      IR1
# 3        4          70       RA         60.0       9550   Pave   NaN      IR1
# 4        5          60       RA         84.0      14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...        ...    ...   ...      ...
# 1455  1456          60       RA         62.0       7917   Pave   NaN      Reg
# 1456  1457          20       RA         85.0      13175   Pave   NaN      Reg
# 1457  1458          70       RA         66.0       9042   Pave   NaN      Reg
# 1458  1459          20       RA         68.0       9717   Pave   NaN      Reg
# 1459  1460          20       RA         75.0       9937   Pave   NaN      Reg
#
# ...

# %%
# Criar uma coluna com nome 'Outliers' =1 para as pessoas que tem o maior e o menor valor de compra
df.loc[(df['SalePrice'] == df['SalePrice'].min()) |  (df['SalePrice'] == df['SalePrice'].max()), 'Outliers'] = 1  # selecionando a casa que tem o menor valor

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  AreaTotal Street Alley LotShape  \
# 0        1          60       RL         65.0       8450   Pave   NaN      Reg
# 1        2          20       RL         80.0       9600   Pave   NaN      Reg
# 2        3          60       RL         68.0      11250   Pave   NaN      IR1
# 3        4          70       RL         60.0       9550   Pave   NaN      IR1
# 4        5          60       RL         84.0      14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...        ...    ...   ...      ...
# 1455  1456          60       RL         62.0       7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0      13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0       9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0       9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0       9937   Pave   NaN      Reg
#
# ...

# %%
# preencher valor faltante com 2
df['Outliers'].fillna(2, inplace=True)

# %%
df['Outliers'].value_counts()
# Out:
# 2.0    1458
# 1.0       2
# Name: Outliers, dtype: int64

# %%
# Adiciona uma coluna na posição que vc quer
df.insert(0, 'Amostra', 4)

# %%
df
# Out:
#       Amostra    Id  MSSubClass MSZoning  LotFrontage  AreaTotal Street Alley  \
# 0           4     1          60       RL         65.0       8450   Pave   NaN
# 1           4     2          20       RL         80.0       9600   Pave   NaN
# 2           4     3          60       RL         68.0      11250   Pave   NaN
# 3           4     4          70       RL         60.0       9550   Pave   NaN
# 4           4     5          60       RL         84.0      14260   Pave   NaN
# ...       ...   ...         ...      ...          ...        ...    ...   ...
# 1455        4  1456          60       RL         62.0       7917   Pave   NaN
# 1456        4  1457          20       RL         85.0      13175   Pave   NaN
# 1457        4  1458          70       RL         66.0       9042   Pave   NaN
# 1458        4  1459          20       RL         68.0       9717   Pave   NaN
# 1459        4  1460          20       RL         75.0       9937   Pave   NaN
#
# ...
