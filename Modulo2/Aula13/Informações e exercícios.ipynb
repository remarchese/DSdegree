# %% [markdown]
# # Informações

# %% [markdown]
# - Dia 03/09: PROVA
#     - 4 questões que envolvem dataframe e visualização de dados, principalmente
# - Dia 01/09: Dúvidas, revião e exercícios
#
# - Dia 30/08: Mini projeto 2 e a entrega será feita até 05/09
#     - As notas serão disponibilizadas pelo github

# %%
import pandas as pd

df = pd.read_csv('C:/Users/Renata/Desktop/participantes_89915828484.csv', header=2)

# %%
df
# Out:
#                            Nome (Nome original)               E-mail do usuário  ... Convidado Permissão de gravação
# 0                                       Eugenio                             NaN  ...       Sim                     Y
# 1                              Humberto Monello                             NaN  ...       Sim                     Y
# 2                                   Pedro Gengo                             NaN  ...       Sim                     Y
# 3                                          Hage              abdohage@gmail.com  ...       Sim                     Y
# 4                            Paulo Odair Frazao    frazaopointevin@yahoo.com.br  ...       Sim                     Y
# 5                                    caio cunha                             NaN  ...       Sim                     Y
# 6                                 tiagomonteiro                             NaN  ...       Sim                     Y
# 7                                    Let's Code  larissa.afonso@letscode.com.br  ...       Não                     Y
# 8                              Diego Zilli Ruiz                             NaN  ...       Sim                     Y
# 9                         Wilian da Silva Ricce                             NaN  ...       Sim                     Y
# 10                                  Edson Rocha                             NaN  ...       Sim                     Y
# 11                    Carlos Eduardo Nascimento     carloseduardo96@hotmail.com  ...       Sim                     Y
# 12                             José Luiz Santos                             NaN  ...       Sim                     Y
# 13                                   Luiz Mukai                             NaN  ...       Sim                     Y
# 14        Daniel Rosa (Stuanor) (Danny El Roza)                             NaN  ...       Sim                     Y
# 15                                        Denis                             NaN  ...       Sim                     Y
# 16                                   Lucas Lima                             NaN  ...       Sim                     Y
# 17                                 Dani Santana                             NaN  ...       Sim                     Y
# 18                                  Diego Abreu                             NaN  ...       Sim                     Y
# 19   Felipe Zarour (carlos felipe mothe zarour)                             NaN  ...       Sim                     Y
# 20                                     anderson                             NaN  ...       Sim                     Y
# 21            W. Alexandre (Prof. W. Alexandre)       professor1406@prof.una.br  ...       Sim                     Y
# 22                                   Felipe Kim                             NaN  ...       Sim                     Y
# 23                                  EDERPUDIESI                             NaN  ...       Sim                     Y
# 24                               Renato Ricarti                             NaN  ...       Sim                     Y
# 25                                Leonardo do Ó                             NaN  ...       Sim                     Y
# 26                                Leonardo do Ó                             NaN  ...       Sim                     Y
# 27                               Bruna Monteiro                             NaN  ...       Sim                     Y
# 28  Alexandre Belisário Duarte Leite de Andrade                             NaN  ...       Sim                     Y
# 29                                 Allan Vilela                             NaN  ...       Sim                     Y
# 30                               Renato Augusto                             NaN  ...       Sim                     Y
# 31                                    luizmukai                             NaN  ...       Sim                     Y
# 32                              Claudio Pereira                             NaN  ...       Sim                     Y
# 33                                 Marco Orides                             NaN  ...       Sim                     Y
# 34                                         Natã                             NaN  ...       Sim                     Y
# 35                                    luizmukai                             NaN  ...       Sim                     Y
# 36                                Jayme Augusto                             NaN  ...       Sim                     Y
# 37                                 Fabio Toledo                             NaN  ...       Sim                     Y
# 38                               Bruno Perrotta        brunodperrotta@gmail.com  ...       Sim                     Y
# 39                                        Silas                             NaN  ...       Sim                     Y
# 40                              Daniel Pinheiro                             NaN  ...       Sim                     Y
# 41                                 Fábio Mendes                             NaN  ...       Sim                     Y
# 42                                Enzo Silverio                             NaN  ...       Sim                     Y
# 43                              Claudio Pereira                             NaN  ...       Sim                     Y
# 44                                André Paraizo       andre.paraizo@hotmail.com  ...       Sim                     Y
# 45                             Breno F. Marques                             NaN  ...       Sim                     Y
# 46                                         Ivan                             NaN  ...       Sim                     Y
# 47                                   Caio cunha                             NaN  ...       Sim                     Y
# 48                      José Luiz Santos (José)                             NaN  ...       Sim                     Y
# 49                             Diego Zilli Ruiz                             NaN  ...       Sim                     Y
# 50                                Danny El Roza                             NaN  ...       Sim                     Y
# 51                             Alexandre Angelo                             NaN  ...       Sim                     Y
#
# [52 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Nome (Nome original)', 'E-mail do usuário', 'Horário de entrada',
#        'Horário de saída', 'Duração (Minutos)', 'Convidado',
#        'Permissão de gravação'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nome (Nome original)   52 non-null     object
#  1   E-mail do usuário      7 non-null      object
#  2   Horário de entrada     52 non-null     object
#  3   Horário de saída       52 non-null     object
#  4   Duração (Minutos)      52 non-null     int64
#  5   Convidado              52 non-null     object
#  6   Permissão de gravação  52 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df.groupby(['Nome (Nome original)'])['Duração (Minutos)'].sum().sort_values()
# Out:
# Nome (Nome original)
# Renato Augusto                                   3
# Caio cunha                                       5
# Hage                                            25
# Lucas Lima                                      29
# caio cunha                                      33
# Danny El Roza                                   57
# José Luiz Santos                                68
# Renato Ricarti                                  98
# Marco Orides                                   109
# José Luiz Santos (José)                        111
# Ivan                                           113
# Breno F. Marques                               122
# Bruno Perrotta                                 123
# Enzo Silverio                                  140
# Daniel Rosa (Stuanor) (Danny El Roza)          143
# Fabio Toledo                                   143
# Bruna Monteiro                                 152
# Dani Santana                                   154
# Fábio Mendes                                   163
# André Paraizo                                  164
# Silas                                          165
# anderson                                       169
# Felipe Kim                                     175
# Natã                                           176
# Daniel Pinheiro                                178
# Denis                                          179
# EDERPUDIESI                                    182
# Felipe Zarour (carlos felipe mothe zarour)     185
# Jayme Augusto                                  188
# Edson Rocha                                    190
# luizmukai                                      191
# Allan Vilela                                   191
# Alexandre Belisário Duarte Leite de Andrade    192
# tiagomonteiro                                  193
# Paulo Odair Frazao                             194
# Claudio Pereira                                196
# Alexandre Angelo                               196
# Diego Abreu                                    199
# Luiz Mukai                                     202
# Diego Zilli Ruiz                               202
# Wilian da Silva Ricce                          204
# Carlos Eduardo Nascimento                      206
# Eugenio                                        209
# Humberto Monello                               210
# W. Alexandre (Prof. W. Alexandre)              274
# Let's Code                                     281
# Pedro Gengo                                    284
# Leonardo do Ó                                  361
# Name: Duração (Minutos), dtype: int64

# %%
import glob
