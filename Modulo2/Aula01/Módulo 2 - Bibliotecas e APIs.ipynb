# %% [markdown]
# # Módulo 2 - Bibliotecas e APIs

# %% [markdown]
# ## Apresentação

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Curso

# %% [markdown]
# Link do github (material de aula, feito em sala):
# https://github.com/renatapink/DSdegree
#
# Aulas são gravadas e disponibilizadas no class

# %% [markdown]
# É interessante que vocês criem uma conta no github

# %% [markdown]
# ### compartilhar código
#
# http://dontpad.com/dsdegree

# %% [markdown]
# ## Instalação e IDE

# %% [markdown]
# Anaconda Navigator
# https://www.anaconda.com/products/individual-b
#
# https://docs.anaconda.com/anaconda/navigator/

# %%
# Criar um ambiente

conda create --name dsdegree python

# Para ver ambientes

conda info --envs

#acessar o ambiente

conda activate dsdegree

#sair do ambiente

conda deactivate

# ver versão do python

python --version

# instalar jupyter notebook

conda install -c anaconda jupyter # [-c é --channel (instalar de um canal específico)]

#abrir
python -m notebook
